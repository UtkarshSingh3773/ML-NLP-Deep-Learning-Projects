# %% [markdown]
# <a href="https://colab.research.google.com/github/UtkarshSingh3773/ML-NLP-Deep-Learning-Projects/blob/main/project_nltk.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install PyMuPDF
# !pip install spacy
# Out:
# Collecting PyMuPDF
#   Downloading pymupdf-1.26.0-cp39-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (3.4 kB)
# Downloading pymupdf-1.26.0-cp39-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (24.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.1/24.1 MB 71.5 MB/s eta 0:00:00
# Installing collected packages: PyMuPDF
# Successfully installed PyMuPDF-1.26.0
# Requirement already satisfied: spacy in /usr/local/lib/python3.11/dist-packages (3.8.6)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.11/dist-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (1.0.12)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.11/dist-packages (from spacy) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.11/dist-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in /usr/local/lib/python3.11/dist-packages (from spacy) (8.3.6)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.11/dist-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.11/dist-packages (from spacy) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.11/dist-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (0.15.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (4.67.1)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (2.0.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.11/dist-packages (from spacy) (2.11.4)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from spacy) (3.1.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from spacy) (75.2.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (24.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (3.5.0)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.11/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.13.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2025.4.26)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from thinc<8.4.0,>=8.3.4->spacy) (1.3.0)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from thinc<8.4.0,>=8.3.4->spacy) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (8.2.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (13.9.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from weasel<0.5.0,>=0.1.0->spacy) (0.21.1)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.11/dist-packages (from weasel<0.5.0,>=0.1.0->spacy) (7.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->spacy) (3.0.2)
# Requirement already satisfied: marisa-trie>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.19.1)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy) (1.17.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)

# %%
import fitz  # PyMuPDF
import spacy

# Define the function with a proper parameter name, e.g., 'pdf_path'
def extract_text_from_pdf(pdf_path):
    # Use the parameter 'pdf_path' to open the file
    doc = fitz.open(pdf_path)
    text = ""
    for page in doc:
        text += page.get_text()
    return text

# Load the English NER model
nlp = spacy.load("en_core_web_sm")

def apply_ner(text, chunk_size=500000): # Added chunk_size parameter
    # Split the text into chunks
    text_chunks = [text[i:i + chunk_size] for i in range(0, len(text), chunk_size)]

    print("Processing text in chunks...")
    for i, chunk in enumerate(text_chunks):
        print(f"Processing chunk {i+1}/{len(text_chunks)}")
        doc = nlp(chunk)
        # Process named entities for the current chunk
        for ent in doc.ents:
            print(f"{ent.text} ({ent.label_}): {spacy.explain(ent.label_)}")

fghfgh = extract_text_from_pdf("/content/john-stuart-mill_system-of-logic.pdf")
apply_ner(fghfgh) # Call the function with the extracted text
# Out:
# Streaming output truncated to the last 5000 lines.
# ten gallons (QUANTITY): Measurements, as of weight or distance
# one gallon (QUANTITY): Measurements, as of weight or distance
# Attributes Concluded (PERSON): People, including fictional
# 13 (CARDINAL): Numerals that do not fall under another type
# Quality or Quantity (ORG): Companies, agencies, institutions, etc.
# Relation (ORG): Companies, agencies, institutions, etc.
# 14 (CARDINAL): Numerals that do not fall under another type
# 46 (CARDINAL): Numerals that do not fall under another type
# two (CARDINAL): Numerals that do not fall under another type
# one (CARDINAL): Numerals that do not fall under another type
# 15 (CARDINAL): Numerals that do not fall under another type
# Feelings (ORG): Companies, agencies, institutions, etc.
# four (CARDINAL): Numerals that do not fall under another type
# Perceptions (PERSON): People, including fictional
# Belief (PERSON): People, including fictional
# Belief (PERSON): People, including fictional
# Feelings (WORK_OF_ART): Titles of books, songs, etc.
# Substances (ORG): Companies, agencies, institutions, etc.
# Bodies (PERSON): People, including fictional
# Minds (PERSON): People, including fictional
# Matter and Mind (WORK_OF_ART): Titles of books, songs, etc.
# Mind (PERSON): People, including fictional
# three (CARDINAL): Numerals that do not fall under another type
# Quality, Relation (ORG): Companies, agencies, institutions, etc.
# Quantity (NORP): Nationalities or religious or political groups
# third (ORDINAL): "first", "second", etc.
# Attribute, Quantity (ORG): Companies, agencies, institutions, etc.
# 47 (CARDINAL): Numerals that do not fall under another type
# States of Consciousness (ORG): Companies, agencies, institutions, etc.
# 2d (CARDINAL): Numerals that do not fall under another type
# Minds (PERSON): People, including fictional
# 3d (CARDINAL): Numerals that do not fall under another type
# Bodies (ORG): Companies, agencies, institutions, etc.
# 4th (ORDINAL): "first", "second", etc.
# Successions (ORG): Companies, agencies, institutions, etc.
# the Likenesses and Unlikenesses (ORG): Companies, agencies, institutions, etc.
# the Import of Propositions (ORG): Companies, agencies, institutions, etc.
# four (CARDINAL): Numerals that do not fall under another type
# 24 (CARDINAL): Numerals that do not fall under another type
# Bain (PERSON): People, including fictional
# i. (ORG): Companies, agencies, institutions, etc.
# 49 (DATE): Absolute or relative dates or periods
# one (CARDINAL): Numerals that do not fall under another type
# Bain (PERSON): People, including fictional
# 48 (CARDINAL): Numerals that do not fall under another type
# Propositions
#
# § 1 (LAW): Named documents made into laws.
# Propositions (FAC): Buildings, airports, highways, bridges, etc.
# Names (ORG): Companies, agencies, institutions, etc.
# two (CARDINAL): Numerals that do not fall under another type
# one (CARDINAL): Numerals that do not fall under another type
# one (CARDINAL): Numerals that do not fall under another type
# second (ORDINAL): "first", "second", etc.
# Socrates (PRODUCT): Objects, vehicles, foods, etc. (not services)
# Socrates (PRODUCT): Objects, vehicles, foods, etc. (not services)
# Socrates (PRODUCT): Objects, vehicles, foods, etc. (not services)
# Ens, (ORG): Companies, agencies, institutions, etc.
# Entitas (ORG): Companies, agencies, institutions, etc.
# Essentia (GPE): Countries, cities, states
# Socrates (PRODUCT): Objects, vehicles, foods, etc. (not services)
# Plato (ORG): Companies, agencies, institutions, etc.
# Aristotle (PERSON): People, including fictional
# Crotona (PERSON): People, including fictional
# Greeks (PERSON): People, including fictional
# One (CARDINAL): Numerals that do not fall under another type
# one (CARDINAL): Numerals that do not fall under another type
# 49 (CARDINAL): Numerals that do not fall under another type
# two (CARDINAL): Numerals that do not fall under another type
# Hobbes (PERSON): People, including fictional
# James MillP24F25 (PERSON): People, including fictional
# first (ORDINAL): "first", "second", etc.
# 2 (CARDINAL): Numerals that do not fall under another type
# first (ORDINAL): "first", "second", etc.
# Cæsar (ORG): Companies, agencies, institutions, etc.
# Cæsar (ORG): Companies, agencies, institutions, etc.
# Hobbes (PERSON): People, including fictional
# only one (CARDINAL): Numerals that do not fall under another type
# Cæsar (ORG): Companies, agencies, institutions, etc.
# Cæsar (ORG): Companies, agencies, institutions, etc.
# second (ORDINAL): "first", "second", etc.
# Cæsar (ORG): Companies, agencies, institutions, etc.
# two (CARDINAL): Numerals that do not fall under another type
# two (CARDINAL): Numerals that do not fall under another type
# i. (ORG): Companies, agencies, institutions, etc.
# 126 (CARDINAL): Numerals that do not fall under another type
# 50 (CARDINAL): Numerals that do not fall under another type
# Cæsar (ORG): Companies, agencies, institutions, etc.
# Cæsar (ORG): Companies, agencies, institutions, etc.
# Cæsar (ORG): Companies, agencies, institutions, etc.
# Cæsar (ORG): Companies, agencies, institutions, etc.
# 3 (CARDINAL): Numerals that do not fall under another type
# Simple and (WORK_OF_ART): Titles of books, songs, etc.
# Complex (NORP): Nationalities or religious or political groups
# Compound (GPE): Countries, cities, states
# one (CARDINAL): Numerals that do not fall under another type
# one (CARDINAL): Numerals that do not fall under another type
# more than one (CARDINAL): Numerals that do not fall under another type
# more than one (CARDINAL): Numerals that do not fall under another type
# first (ORDINAL): "first", "second", etc.
# one (CARDINAL): Numerals that do not fall under another type
# more than one (CARDINAL): Numerals that do not fall under another type
# Brutus (PERSON): People, including fictional
# Cæsar (ORG): Companies, agencies, institutions, etc.
# Brutus (PERSON): People, including fictional
# two (CARDINAL): Numerals that do not fall under another type
# two (CARDINAL): Numerals that do not fall under another type
# two (CARDINAL): Numerals that do not fall under another type
# third (ORDINAL): "first", "second", etc.
# Cæsar (ORG): Companies, agencies, institutions, etc.
# Brutus (PERSON): People, including fictional
# Cæsar (ORG): Companies, agencies, institutions, etc.
# Brutus (PERSON): People, including fictional
# two (CARDINAL): Numerals that do not fall under another type
# Cæsar (ORG): Companies, agencies, institutions, etc.
# Brutus (PERSON): People, including fictional
# three (CARDINAL): Numerals that do not fall under another type
# fourth (ORDINAL): "first", "second", etc.
# two (CARDINAL): Numerals that do not fall under another type
# two (CARDINAL): Numerals that do not fall under another type
# two (CARDINAL): Numerals that do not fall under another type
# brevity (CARDINAL): Numerals that do not fall under another type
# Peter (PERSON): People, including fictional
# James (PERSON): People, including fictional
# Jerusalem (GPE): Countries, cities, states
# Galilee (GPE): Countries, cities, states
# four (CARDINAL): Numerals that do not fall under another type
# Peter (PERSON): People, including fictional
# Jerusalem (GPE): Countries, cities, states
# Peter (PERSON): People, including fictional
# Galilee (GPE): Countries, cities, states
# James (PERSON): People, including fictional
# Jerusalem (GPE): Countries, cities, states
# James (PERSON): People, including fictional
# Galilee (GPE): Countries, cities, states
# two (CARDINAL): Numerals that do not fall under another type
# 26 (CARDINAL): Numerals that do not fall under another type
# i. (ORG): Companies, agencies, institutions, etc.
# 85 (DATE): Absolute or relative dates or periods
# 51 (CARDINAL): Numerals that do not fall under another type
# one (CARDINAL): Numerals that do not fall under another type
# one (CARDINAL): Numerals that do not fall under another type
# D. (NORP): Nationalities or religious or political groups
# Archbishop Whately (ORG): Companies, agencies, institutions, etc.
# two (CARDINAL): Numerals that do not fall under another type
# Koran (WORK_OF_ART): Titles of books, songs, etc.
# Mohammed (PERSON): People, including fictional
# Koran (WORK_OF_ART): Titles of books, songs, etc.
# Mohammed (PERSON): People, including fictional
# The Koran (WORK_OF_ART): Titles of books, songs, etc.
# Koran (WORK_OF_ART): Titles of books, songs, etc.
# Mohammed (PERSON): People, including fictional
# Mohammed (PERSON): People, including fictional
# The
# Koran (WORK_OF_ART): Titles of books, songs, etc.
# first (ORDINAL): "first", "second", etc.
# one (CARDINAL): Numerals that do not fall under another type
# one (CARDINAL): Numerals that do not fall under another type
# only one (CARDINAL): Numerals that do not fall under another type
# the Greek
# Church (ORG): Companies, agencies, institutions, etc.
# Parliament (ORG): Companies, agencies, institutions, etc.
# the
# Revolution: (EVENT): Named hurricanes, battles, wars, sports events, etc.
# 52 (CARDINAL): Numerals that do not fall under another type
# one (CARDINAL): Numerals that do not fall under another type
# 4 (CARDINAL): Numerals that do not fall under another type
# Propositions (FAC): Buildings, airports, highways, bridges, etc.
# Indefinite (NORP): Nationalities or religious or political groups
# Singular (ORG): Companies, agencies, institutions, etc.
# Julius Cæsar (PERSON): People, including fictional
# Singular (GPE): Countries, cities, states
# Singular (ORG): Companies, agencies, institutions, etc.
# The Founder of Christianity (WORK_OF_ART): Titles of books, songs, etc.
# one (CARDINAL): Numerals that do not fall under another type
# Indefinite (ORG): Companies, agencies, institutions, etc.
# Archbishop Whately (ORG): Companies, agencies, institutions, etc.
# grammarians (NORP): Nationalities or religious or political groups
# 27 (CARDINAL): Numerals that do not fall under another type
# Bain (PERSON): People, including fictional
# i. (ORG): Companies, agencies, institutions, etc.
# 81 (DATE): Absolute or relative dates or periods
# Total and Partial (WORK_OF_ART): Titles of books, songs, etc.
# Singular (ORG): Companies, agencies, institutions, etc.
# Universal (ORG): Companies, agencies, institutions, etc.
# Subject (PERSON): People, including fictional
# only one (CARDINAL): Numerals that do not fall under another type
# Subject (PERSON): People, including fictional
# Universal (PERSON): People, including fictional
# Bain (PERSON): People, including fictional
# 53 (CARDINAL): Numerals that do not fall under another type
# two (CARDINAL): Numerals that do not fall under another type
# Bain (PERSON): People, including fictional
# Indefinite (NORP): Nationalities or religious or political groups
# Mortal (PERSON): People, including fictional
# 28 (CARDINAL): Numerals that do not fall under another type
# 29 (CARDINAL): Numerals that do not fall under another type
# i. (ORG): Companies, agencies, institutions, etc.
# 82 (CARDINAL): Numerals that do not fall under another type
# 54 (CARDINAL): Numerals that do not fall under another type
# The Import Of Propositions
#
# § (ORG): Companies, agencies, institutions, etc.
# 1 (CARDINAL): Numerals that do not fall under another type
# one (CARDINAL): Numerals that do not fall under another type
# two (CARDINAL): Numerals that do not fall under another type
# Belief (LAW): Named documents made into laws.
# Descartes (GPE): Countries, cities, states
# Leibnitz (PERSON): People, including fictional
# Locke (WORK_OF_ART): Titles of books, songs, etc.
# Propositions (FAC): Buildings, airports, highways, bridges, etc.
# Judgment (ORG): Companies, agencies, institutions, etc.
# Logic (ORG): Companies, agencies, institutions, etc.
# the last two centuries (DATE): Absolute or relative dates or periods
# English (LANGUAGE): Any named language
# German (NORP): Nationalities or religious or political groups
# French (NORP): Nationalities or religious or political groups
# two (CARDINAL): Numerals that do not fall under another type
# one (CARDINAL): Numerals that do not fall under another type
# two (CARDINAL): Numerals that do not fall under another type
# one (CARDINAL): Numerals that do not fall under another type
# two (CARDINAL): Numerals that do not fall under another type
# between two (CARDINAL): Numerals that do not fall under another type
# Ideas (GPE): Countries, cities, states
# two (CARDINAL): Numerals that do not fall under another type
# first (ORDINAL): "first", "second", etc.
# two (CARDINAL): Numerals that do not fall under another type
# Mohammed (PERSON): People, including fictional
# Mohammed (PERSON): People, including fictional
# two (CARDINAL): Numerals that do not fall under another type
# 55 (CARDINAL): Numerals that do not fall under another type
# one (CARDINAL): Numerals that do not fall under another type
# Deity (ORG): Companies, agencies, institutions, etc.
# two (CARDINAL): Numerals that do not fall under another type
# two (CARDINAL): Numerals that do not fall under another type
# one (CARDINAL): Numerals that do not fall under another type
# Logic (ORG): Companies, agencies, institutions, etc.
# the last two centuries (DATE): Absolute or relative dates or periods
# Logic (ORG): Companies, agencies, institutions, etc.
# Mental Philosophy (ORG): Companies, agencies, institutions, etc.
# second (ORDINAL): "first", "second", etc.
# Judgment and Reasoning (ORG): Companies, agencies, institutions, etc.
# Logic (ORG): Companies, agencies, institutions, etc.
# Judgment (ORG): Companies, agencies, institutions, etc.
# 2 (CARDINAL): Numerals that do not fall under another type
# One (CARDINAL): Numerals that do not fall under another type
# Hobbes (PERSON): People, including fictional
# six feet (QUANTITY): Measurements, as of weight or distance
# 30 (CARDINAL): Numerals that do not fall under another type
# Whewell (PERSON): People, including fictional
# 242 (CARDINAL): Numerals that do not fall under another type
# 56 (CARDINAL): Numerals that do not fall under another type
# six feet (QUANTITY): Measurements, as of weight or distance
# one (CARDINAL): Numerals that do not fall under another type
# two (CARDINAL): Numerals that do not fall under another type
# Hobbes (PERSON): People, including fictional
# one (CARDINAL): Numerals that do not fall under another type
# two (CARDINAL): Numerals that do not fall under another type
# one (CARDINAL): Numerals that do not fall under another type
# two (CARDINAL): Numerals that do not fall under another type
# Hobbes (PERSON): People, including fictional
# Hobbes (PERSON): People, including fictional
# Hyde (PERSON): People, including fictional
# Clarendon (PERSON): People, including fictional
# Tully (PERSON): People, including fictional
# Cicero (ORG): Companies, agencies, institutions, etc.
# Hobbes (PERSON): People, including fictional
# Nominalists (ORG): Companies, agencies, institutions, etc.
# first (ORDINAL): "first", "second", etc.
# only one (CARDINAL): Numerals that do not fall under another type
# 57 (CARDINAL): Numerals that do not fall under another type
# Socrates (PRODUCT): Objects, vehicles, foods, etc. (not services)
# Socrates (PRODUCT): Objects, vehicles, foods, etc. (not services)
# Socrates (PRODUCT): Objects, vehicles, foods, etc. (not services)
# Socrates (PRODUCT): Objects, vehicles, foods, etc. (not services)
# Smith, Brown (ORG): Companies, agencies, institutions, etc.
# one (CARDINAL): Numerals that do not fall under another type
# Hobbes (GPE): Countries, cities, states
# two (CARDINAL): Numerals that do not fall under another type
# two (CARDINAL): Numerals that do not fall under another type
# two (CARDINAL): Numerals that do not fall under another type
# Diamond (ORG): Companies, agencies, institutions, etc.
# Combustible (ORG): Companies, agencies, institutions, etc.
# first (ORDINAL): "first", "second", etc.
# 3 (CARDINAL): Numerals that do not fall under another type
# Hobbes (PERSON): People, including fictional
# Predication (ORG): Companies, agencies, institutions, etc.
# Predication (PRODUCT): Objects, vehicles, foods, etc. (not services)
# one (CARDINAL): Numerals that do not fall under another type
# Plato (PERSON): People, including fictional
# Plato (ORG): Companies, agencies, institutions, etc.
# 58 (CARDINAL): Numerals that do not fall under another type
# Predication (PRODUCT): Objects, vehicles, foods, etc. (not services)
# Hobbes (GPE): Countries, cities, states
# 59 (CARDINAL): Numerals that do not fall under another type
# Aristotle (PERSON): People, including fictional
# Ideas (GPE): Countries, cities, states
# Names (ORG): Companies, agencies, institutions, etc.
# Hobbes (PERSON): People, including fictional
# Predication (ORG): Companies, agencies, institutions, etc.
# Leibnitz (PERSON): People, including fictional
# Hobbes (NORP): Nationalities or religious or political groups
# Hobbes (PERSON): People, including fictional
# Hobbes (PERSON): People, including fictional
# 31 (CARDINAL): Numerals that do not fall under another type
# Bain (PERSON): People, including fictional
# i. (ORG): Companies, agencies, institutions, etc.
# 50 (DATE): Absolute or relative dates or periods
# two (CARDINAL): Numerals that do not fall under another type
# the Peers of the Realm (ORG): Companies, agencies, institutions, etc.
# Logic (ORG): Companies, agencies, institutions, etc.
# Vide (ORG): Companies, agencies, institutions, etc.
# 3 (CARDINAL): Numerals that do not fall under another type
# 2. (CARDINAL): Numerals that do not fall under another type
# 32 (CARDINAL): Numerals that do not fall under another type
# first (ORDINAL): "first", "second", etc.
# first (ORDINAL): "first", "second", etc.
# 8. (CARDINAL): Numerals that do not fall under another type
# 33 (CARDINAL): Numerals that do not fall under another type
# Tacit (ORG): Companies, agencies, institutions, etc.
# one (CARDINAL): Numerals that do not fall under another type
# 1. (CARDINAL): Numerals that do not fall under another type
# 60 (CARDINAL): Numerals that do not fall under another type
# one (CARDINAL): Numerals that do not fall under another type
# 4 (CARDINAL): Numerals that do not fall under another type
# first (ORDINAL): "first", "second", etc.
# Chimborazo (NORP): Nationalities or religious or political groups
# Chimborazo (NORP): Nationalities or religious or political groups
# John (PERSON): People, including fictional
# Thomas (PERSON): People, including fictional
# 3 (CARDINAL): Numerals that do not fall under another type
# 35 (CARDINAL): Numerals that do not fall under another type
# 77 (CARDINAL): Numerals that do not fall under another type
# William Hamilton (PERSON): People, including fictional
# xxii (GPE): Countries, cities, states
# 61 (CARDINAL): Numerals that do not fall under another type
# one (CARDINAL): Numerals that do not fall under another type
# one (CARDINAL): Numerals that do not fall under another type
# one (CARDINAL): Numerals that do not fall under another type
# 5 (CARDINAL): Numerals that do not fall under another type
# Hobbes (GPE): Countries, cities, states
# two (CARDINAL): Numerals that do not fall under another type
# two (CARDINAL): Numerals that do not fall under another type
# two (CARDINAL): Numerals that do not fall under another type
# two (CARDINAL): Numerals that do not fall under another type
# Phenomena (ORG): Companies, agencies, institutions, etc.
# two (CARDINAL): Numerals that do not fall under another type
# Worthy (PERSON): People, including fictional
# Worthy (PERSON): People, including fictional
# two (CARDINAL): Numerals that do not fall under another type
# two (CARDINAL): Numerals that do not fall under another type
# one (CARDINAL): Numerals that do not fall under another type
# 62 (CARDINAL): Numerals that do not fall under another type
# one (CARDINAL): Numerals that do not fall under another type
# first (ORDINAL): "first", "second", etc.
# Phenomena (ORG): Companies, agencies, institutions, etc.
# Phenomena (ORG): Companies, agencies, institutions, etc.
# Socrates (PERSON): People, including fictional
# Peloponnesian (NORP): Nationalities or religious or political groups
# Socrates (PRODUCT): Objects, vehicles, foods, etc. (not services)
# Peloponnesian (NORP): Nationalities or religious or political groups
# Thing (ORG): Companies, agencies, institutions, etc.
# Socrates (PRODUCT): Objects, vehicles, foods, etc. (not services)
# two (CARDINAL): Numerals that do not fall under another type
# Sequence (ORG): Companies, agencies, institutions, etc.
# Causation (ORG): Companies, agencies, institutions, etc.
# 36 (CARDINAL): Numerals that do not fall under another type
# Bain (PERSON): People, including fictional
# 256 (CARDINAL): Numerals that do not fall under another type
# Existence (PERSON): People, including fictional
# Deity (ORG): Companies, agencies, institutions, etc.
# the First Cause of the Universe (ORG): Companies, agencies, institutions, etc.
# Cause (GPE): Countries, cities, states
# i. (ORG): Companies, agencies, institutions, etc.
# 407 (CARDINAL): Numerals that do not fall under another type
# Bain (PERSON): People, including fictional
# Nature (WORK_OF_ART): Titles of books, songs, etc.
# Exists (NORP): Nationalities or religious or political groups
# Law of Relativity (WORK_OF_ART): Titles of books, songs, etc.
# Bain (PERSON): People, including fictional
# two (CARDINAL): Numerals that do not fall under another type
# Nonentity (ORG): Companies, agencies, institutions, etc.
# Nonentity (ORG): Companies, agencies, institutions, etc.
# Existence (PERSON): People, including fictional
# Causation (ORG): Companies, agencies, institutions, etc.
# Existence (PERSON): People, including fictional
# 63 (CARDINAL): Numerals that do not fall under another type
# 6 (CARDINAL): Numerals that do not fall under another type
# four (CARDINAL): Numerals that do not fall under another type
# fifth (ORDINAL): "first", "second", etc.
# Resemblance (PERSON): People, including fictional
# yesterday (DATE): Absolute or relative dates or periods
# two (CARDINAL): Numerals that do not fall under another type
# two (CARDINAL): Numerals that do not fall under another type
# Gold (PERSON): People, including fictional
# Socrates (PRODUCT): Objects, vehicles, foods, etc. (not services)
# Socrates (PRODUCT): Objects, vehicles, foods, etc. (not services)
# Christians (NORP): Nationalities or religious or political groups
# Christians (NORP): Nationalities or religious or political groups
# some time ago (DATE): Absolute or relative dates or periods
# Hegel (PERSON): People, including fictional
# Being (PERSON): People, including fictional
# 37 (CARDINAL): Numerals that do not fall under another type
# 4 (CARDINAL): Numerals that do not fall under another type
# 7 (CARDINAL): Numerals that do not fall under another type
# 64 (CARDINAL): Numerals that do not fall under another type
# two (CARDINAL): Numerals that do not fall under another type
# yesterday (DATE): Absolute or relative dates or periods
# Resemblance (PERSON): People, including fictional
# Sequence (PERSON): People, including fictional
# one (CARDINAL): Numerals that do not fall under another type
# five (CARDINAL): Numerals that do not fall under another type
# two (CARDINAL): Numerals that do not fall under another type
# Propositions of Co-existence (ORG): Companies, agencies, institutions, etc.
# one (CARDINAL): Numerals that do not fall under another type
# Order in Place (ORG): Companies, agencies, institutions, etc.
# Bain Co-inherence (PERSON): People, including fictional
# Propositions of Co-existence (ORG): Companies, agencies, institutions, etc.
# two (CARDINAL): Numerals that do not fall under another type
# 38 (CARDINAL): Numerals that do not fall under another type
# i. (ORG): Companies, agencies, institutions, etc.
# 103 (CARDINAL): Numerals that do not fall under another type
# 65 (CARDINAL): Numerals that do not fall under another type
# Attribute (ORG): Companies, agencies, institutions, etc.
# two (CARDINAL): Numerals that do not fall under another type
# two (CARDINAL): Numerals that do not fall under another type
# morning (TIME): Times smaller than a day
# Order in Place (ORG): Companies, agencies, institutions, etc.
# Time (ORG): Companies, agencies, institutions, etc.
# Sequence (PERSON): People, including fictional
# Sequence (PERSON): People, including fictional
# Order (ORG): Companies, agencies, institutions, etc.
# one (CARDINAL): Numerals that do not fall under another type
# five (CARDINAL): Numerals that do not fall under another type
# Causation (WORK_OF_ART): Titles of books, songs, etc.
# Sequence (GPE): Countries, cities, states
# Resemblance (GPE): Countries, cities, states
# five (CARDINAL): Numerals that do not fall under another type
# Existence (PERSON): People, including fictional
# Causation (EVENT): Named hurricanes, battles, wars, sports events, etc.
# Sequence (GPE): Countries, cities, states
# Resemblance (GPE): Countries, cities, states
# Thoughtlessness (ORG): Companies, agencies, institutions, etc.
# Thoughtless (ORG): Companies, agencies, institutions, etc.
# 66 (CARDINAL): Numerals that do not fall under another type
# Whiteness (ORG): Companies, agencies, institutions, etc.
# Resemblance (GPE): Countries, cities, states
# one (CARDINAL): Numerals that do not fall under another type
# two (CARDINAL): Numerals that do not fall under another type
# first (ORDINAL): "first", "second", etc.
# Prudence (GPE): Countries, cities, states
# one (CARDINAL): Numerals that do not fall under another type
# five (CARDINAL): Numerals that do not fall under another type
# Existence (PERSON): People, including fictional
# Sequence (ORG): Companies, agencies, institutions, etc.
# Causation (WORK_OF_ART): Titles of books, songs, etc.
# Resemblance (GPE): Countries, cities, states
# 67 (CARDINAL): Numerals that do not fall under another type
# five (CARDINAL): Numerals that do not fall under another type
# 68 (CARDINAL): Numerals that do not fall under another type
# Propositions Merely Verbal
#
# § (ORG): Companies, agencies, institutions, etc.
# 1 (CARDINAL): Numerals that do not fall under another type
# Logic (ORG): Companies, agencies, institutions, etc.
# Propositions (FAC): Buildings, airports, highways, bridges, etc.
# Conceptualists (NORP): Nationalities or religious or political groups
# two (CARDINAL): Numerals that do not fall under another type
# Nominalists (ORG): Companies, agencies, institutions, etc.
# two (CARDINAL): Numerals that do not fall under another type
# Propositions (FAC): Buildings, airports, highways, bridges, etc.
# five (CARDINAL): Numerals that do not fall under another type
# Existence (PERSON): People, including fictional
# five (CARDINAL): Numerals that do not fall under another type
# one (CARDINAL): Numerals that do not fall under another type
# Hobbes (PERSON): People, including fictional
# first (ORDINAL): "first", "second", etc.
# the present day (DATE): Absolute or relative dates or periods
# 2 (CARDINAL): Numerals that do not fall under another type
# Locke (WORK_OF_ART): Titles of books, songs, etc.
# 69 (CARDINAL): Numerals that do not fall under another type
# Accidental Propositions (ORG): Companies, agencies, institutions, etc.
# substantiæ secundæ (PERSON): People, including fictional
# Aristotelian (NORP): Nationalities or religious or political groups
# Platonic (NORP): Nationalities or religious or political groups
# one (CARDINAL): Numerals that do not fall under another type
# one (CARDINAL): Numerals that do not fall under another type
# Aristotelians (NORP): Nationalities or religious or political groups
# Locke (WORK_OF_ART): Titles of books, songs, etc.
# the seventeenth century (DATE): Absolute or relative dates or periods
# one (CARDINAL): Numerals that do not fall under another type
# one (CARDINAL): Numerals that do not fall under another type
# 39 (CARDINAL): Numerals that do not fall under another type
# Aristotle (PERSON): People, including fictional
# the Middle Ages (LOC): Non-GPE locations, mountain ranges, bodies of water
# Substantiæ Secundæ (PERSON): People, including fictional
# 70 (CARDINAL): Numerals that do not fall under another type
# one (CARDINAL): Numerals that do not fall under another type
# 3 (CARDINAL): Numerals that do not fall under another type
# Julius Cæsar (PERSON): People, including fictional
# 71 (CARDINAL): Numerals that do not fall under another type
# John Thompson (PERSON): People, including fictional
# Thompson (ORG): Companies, agencies, institutions, etc.
# Julius Cæsar (PERSON): People, including fictional
# Thompson (ORG): Companies, agencies, institutions, etc.
# John Thompson's (PERSON): People, including fictional
# Locke (WORK_OF_ART): Titles of books, songs, etc.
# two (CARDINAL): Numerals that do not fall under another type
# Nominal (PERSON): People, including fictional
# third (ORDINAL): "first", "second", etc.
# Locke's Essay (WORK_OF_ART): Titles of books, songs, etc.
# Abstract Ideas (WORK_OF_ART): Titles of books, songs, etc.
# Third Book (PERSON): People, including fictional
# Demonstration (ORG): Companies, agencies, institutions, etc.
# one (CARDINAL): Numerals that do not fall under another type
# 4 (CARDINAL): Numerals that do not fall under another type
# Real Propositions (PRODUCT): Objects, vehicles, foods, etc. (not services)
# Verbal (ORG): Companies, agencies, institutions, etc.
# 40 (CARDINAL): Numerals that do not fall under another type
# An Outline of Sematology (ORG): Companies, agencies, institutions, etc.
# B. H. Smart (PERSON): People, including fictional
# Locke (WORK_OF_ART): Titles of books, songs, etc.
# the Idea of’  (WORK_OF_ART): Titles of books, songs, etc.
# 10 (CARDINAL): Numerals that do not fall under another type
# Locke (WORK_OF_ART): Titles of books, songs, etc.
# Idea (ORG): Companies, agencies, institutions, etc.
# one (CARDINAL): Numerals that do not fall under another type
# Propositions (FAC): Buildings, airports, highways, bridges, etc.
# Conceptualist (NORP): Nationalities or religious or political groups
# Idea (ORG): Companies, agencies, institutions, etc.
# Knowledge (PERSON): People, including fictional
# Belief (PERSON): People, including fictional
# 72 (CARDINAL): Numerals that do not fall under another type
# Predicamental Tree (WORK_OF_ART): Titles of books, songs, etc.
# Omne (ORG): Companies, agencies, institutions, etc.
# Omne (ORG): Companies, agencies, institutions, etc.
# Omnis (NORP): Nationalities or religious or political groups
# Omnis (NORP): Nationalities or religious or political groups
# Omnis (NORP): Nationalities or religious or political groups
# 5 (CARDINAL): Numerals that do not fall under another type
# two (CARDINAL): Numerals that do not fall under another type
# one (CARDINAL): Numerals that do not fall under another type
# one (CARDINAL): Numerals that do not fall under another type
# two (CARDINAL): Numerals that do not fall under another type
# two (CARDINAL): Numerals that do not fall under another type
# one (CARDINAL): Numerals that do not fall under another type
# Reasoning (GPE): Countries, cities, states
# 41 (CARDINAL): Numerals that do not fall under another type
# Kant (PERSON): People, including fictional
# 73 (CARDINAL): Numerals that do not fall under another type
# one (CARDINAL): Numerals that do not fall under another type
# Theory (ORG): Companies, agencies, institutions, etc.
# 74 (CARDINAL): Numerals that do not fall under another type
# The Nature Of Classification (WORK_OF_ART): Titles of books, songs, etc.
# 1 (CARDINAL): Numerals that do not fall under another type
# Classification (ORG): Companies, agencies, institutions, etc.
# Realist (NORP): Nationalities or religious or political groups
# General Substances (ORG): Companies, agencies, institutions, etc.
# only one (CARDINAL): Numerals that do not fall under another type
# Christian (NORP): Nationalities or religious or political groups
# Jew (PERSON): People, including fictional
# Polytheist (NORP): Nationalities or religious or political groups
# only one (CARDINAL): Numerals that do not fall under another type
# Predication (ORG): Companies, agencies, institutions, etc.
# Classification (ORG): Companies, agencies, institutions, etc.
# Classification (ORG): Companies, agencies, institutions, etc.
# Cuvier (ORG): Companies, agencies, institutions, etc.
# Plantigrades (ORG): Companies, agencies, institutions, etc.
# Digitigrades (GPE): Countries, cities, states
# Classification (ORG): Companies, agencies, institutions, etc.
# Classification (ORG): Companies, agencies, institutions, etc.
# 75 (CARDINAL): Numerals that do not fall under another type
# 2 (CARDINAL): Numerals that do not fall under another type
# Aristotle (ORG): Companies, agencies, institutions, etc.
# five (CARDINAL): Numerals that do not fall under another type
# one (CARDINAL): Numerals that do not fall under another type
# John (PERSON): People, including fictional
# Substance (ORG): Companies, agencies, institutions, etc.
# one (CARDINAL): Numerals that do not fall under another type
# one (CARDINAL): Numerals that do not fall under another type
# 3 (CARDINAL): Numerals that do not fall under another type
# five (CARDINAL): Numerals that do not fall under another type
# two (CARDINAL): Numerals that do not fall under another type
# Genus (LOC): Non-GPE locations, mountain ranges, bodies of water
# two (CARDINAL): Numerals that do not fall under another type
# one (CARDINAL): Numerals that do not fall under another type
# Genus (FAC): Buildings, airports, highways, bridges, etc.
# Animal (NORP): Nationalities or religious or political groups
# Mathematician (NORP): Nationalities or religious or political groups
# Brute (ORG): Companies, agencies, institutions, etc.
# two (CARDINAL): Numerals that do not fall under another type
# two (CARDINAL): Numerals that do not fall under another type
# two (CARDINAL): Numerals that do not fall under another type
# Mathematician (NORP): Nationalities or religious or political groups
# two (CARDINAL): Numerals that do not fall under another type
# Genus and Species (WORK_OF_ART): Titles of books, songs, etc.
# 76 (CARDINAL): Numerals that do not fall under another type
# two (CARDINAL): Numerals that do not fall under another type
# Aristotelian (NORP): Nationalities or religious or political groups
# Realists (ORG): Companies, agencies, institutions, etc.
# Aristotelians (NORP): Nationalities or religious or political groups
# 4 (CARDINAL): Numerals that do not fall under another type
# two (CARDINAL): Numerals that do not fall under another type
# 77 (CARDINAL): Numerals that do not fall under another type
# hundred (CARDINAL): Numerals that do not fall under another type
# two (CARDINAL): Numerals that do not fall under another type
# one (CARDINAL): Numerals that do not fall under another type
# one (CARDINAL): Numerals that do not fall under another type
# one (CARDINAL): Numerals that do not fall under another type
# Aristotelian (NORP): Nationalities or religious or political groups
# the present day (DATE): Absolute or relative dates or periods
# 78 (CARDINAL): Numerals that do not fall under another type
# two (CARDINAL): Numerals that do not fall under another type
# Isaac Newton (PERSON): People, including fictional
# Newton (GPE): Countries, cities, states
# Christian (NORP): Nationalities or religious or political groups
# Englishman (PERSON): People, including fictional
# Mathematician (NORP): Nationalities or religious or political groups
# Kinds (GPE): Countries, cities, states
# Christian (NORP): Nationalities or religious or political groups
# Christianity (NORP): Nationalities or religious or political groups
# Christianity (NORP): Nationalities or religious or political groups
# Christians (NORP): Nationalities or religious or political groups
# Christian (NORP): Nationalities or religious or political groups
# Mathematician (NORP): Nationalities or religious or political groups
# Kinds (GPE): Countries, cities, states
# two (CARDINAL): Numerals that do not fall under another type
# Christian (NORP): Nationalities or religious or political groups
# Jew (NORP): Nationalities or religious or political groups
# Mussulman (PERSON): People, including fictional
# Pagan (GPE): Countries, cities, states
# Kinds (GPE): Countries, cities, states
# Caucasian (GPE): Countries, cities, states
# Mongolian (NORP): Nationalities or religious or political groups
# Negro (ORG): Companies, agencies, institutions, etc.
# Kind (PERSON): People, including fictional
# Kind (PERSON): People, including fictional
# Kind (PERSON): People, including fictional
# Socrates (PRODUCT): Objects, vehicles, foods, etc. (not services)
# Kind (PERSON): People, including fictional
# Socrates (PRODUCT): Objects, vehicles, foods, etc. (not services)
# Socrates (PRODUCT): Objects, vehicles, foods, etc. (not services)
# Socrates (PRODUCT): Objects, vehicles, foods, etc. (not services)
# Kind (PERSON): People, including fictional
# 79 (CARDINAL): Numerals that do not fall under another type
# Kind (PERSON): People, including fictional
# Kind (PERSON): People, including fictional
# Kinds (GPE): Countries, cities, states
# Kind (PERSON): People, including fictional
# Kind (PERSON): People, including fictional
# Kind (PERSON): People, including fictional
# Kinds (GPE): Countries, cities, states
# Prædicabilis (PERSON): People, including fictional
# Species Subjicibilis (GPE): Countries, cities, states
# Kind (PERSON): People, including fictional
# Kinds (GPE): Countries, cities, states
# three (CARDINAL): Numerals that do not fall under another type
# Differentia (GPE): Countries, cities, states
# Proprium (GPE): Countries, cities, states
# Accidens (PERSON): People, including fictional
# 5 (CARDINAL): Numerals that do not fall under another type
# Differentia (GPE): Countries, cities, states
# Kind (PERSON): People, including fictional
# Kinds (GPE): Countries, cities, states
# one (CARDINAL): Numerals that do not fall under another type
# Differentia (ORG): Companies, agencies, institutions, etc.
# Aristotelians (NORP): Nationalities or religious or political groups
# Kinds (GPE): Countries, cities, states
# Kind (PERSON): People, including fictional
# Logicians (NORP): Nationalities or religious or political groups
# logicians (NORP): Nationalities or religious or political groups
# 80 (CARDINAL): Numerals that do not fall under another type
# Differentia, Proprium (ORG): Companies, agencies, institutions, etc.
# Accidens (PERSON): People, including fictional
# Aristotelians (ORG): Companies, agencies, institutions, etc.
# Houyhnhnms (PERSON): People, including fictional
# 6 (CARDINAL): Numerals that do not fall under another type
# two (CARDINAL): Numerals that do not fall under another type
# Cuvier (ORG): Companies, agencies, institutions, etc.
# Kinds (GPE): Countries, cities, states
# 81 (CARDINAL): Numerals that do not fall under another type
# one (CARDINAL): Numerals that do not fall under another type
# Kind (PERSON): People, including fictional
# four (CARDINAL): Numerals that do not fall under another type
# three (CARDINAL): Numerals that do not fall under another type
# Genus (FAC): Buildings, airports, highways, bridges, etc.
# Species (ORG): Companies, agencies, institutions, etc.
# Linnæan (FAC): Buildings, airports, highways, bridges, etc.
# two (CARDINAL): Numerals that do not fall under another type
# Linnæus (GPE): Countries, cities, states
# three (CARDINAL): Numerals that do not fall under another type
# Linnæan (PRODUCT): Objects, vehicles, foods, etc. (not services)
# two (CARDINAL): Numerals that do not fall under another type
# 82 (CARDINAL): Numerals that do not fall under another type
# Genus (LOC): Non-GPE locations, mountain ranges, bodies of water
# Differentia (ORG): Companies, agencies, institutions, etc.
# two (CARDINAL): Numerals that do not fall under another type
# first (ORDINAL): "first", "second", etc.
# three (CARDINAL): Numerals that do not fall under another type
# Aristotelian (NORP): Nationalities or religious or political groups
# Genus (LOC): Non-GPE locations, mountain ranges, bodies of water
# Differentia (GPE): Countries, cities, states
# Proprium (PERSON): People, including fictional
# Accidens (PERSON): People, including fictional
# Accidens (PERSON): People, including fictional
# one (CARDINAL): Numerals that do not fall under another type
# Proprium (ORG): Companies, agencies, institutions, etc.
# Accidens (PERSON): People, including fictional
# Propria (GPE): Countries, cities, states
# Propria (GPE): Countries, cities, states
# Accidens (PERSON): People, including fictional
# Accidens (PERSON): People, including fictional
# One (CARDINAL): Numerals that do not fall under another type
# two (CARDINAL): Numerals that do not fall under another type
# two (CARDINAL): Numerals that do not fall under another type
# four (CARDINAL): Numerals that do not fall under another type
# first (ORDINAL): "first", "second", etc.
# second (ORDINAL): "first", "second", etc.
# one (CARDINAL): Numerals that do not fall under another type
# 42 (CARDINAL): Numerals that do not fall under another type
# Kinds (GPE): Countries, cities, states
# 83 (CARDINAL): Numerals that do not fall under another type
# two (CARDINAL): Numerals that do not fall under another type
# Proprium (ORG): Companies, agencies, institutions, etc.
# 8 (CARDINAL): Numerals that do not fall under another type
# Accidens (PERSON): People, including fictional
# Separable (WORK_OF_ART): Titles of books, songs, etc.
# Inseparable Accidents (ORG): Companies, agencies, institutions, etc.
# Crow (PERSON): People, including fictional
# Separable Accidents (WORK_OF_ART): Titles of books, songs, etc.
# European (NORP): Nationalities or religious or political groups
# one (CARDINAL): Numerals that do not fall under another type
# one (CARDINAL): Numerals that do not fall under another type
# 84 (CARDINAL): Numerals that do not fall under another type
# 1 (CARDINAL): Numerals that do not fall under another type
# One (CARDINAL): Numerals that do not fall under another type
# Names (ORG): Companies, agencies, institutions, etc.
# Definitions (ORG): Companies, agencies, institutions, etc.
# John Thomson (PERSON): People, including fictional
# Thomson (PERSON): People, including fictional
# John
# Thomson (PERSON): People, including fictional
# John Thomson (PERSON): People, including fictional
# two (CARDINAL): Numerals that do not fall under another type
# 85 (CARDINAL): Numerals that do not fall under another type
# two (CARDINAL): Numerals that do not fall under another type
# three (CARDINAL): Numerals that do not fall under another type
# Condillac (ORG): Companies, agencies, institutions, etc.
# one (CARDINAL): Numerals that do not fall under another type
# two (CARDINAL): Numerals that do not fall under another type
# 2 (CARDINAL): Numerals that do not fall under another type
# two (CARDINAL): Numerals that do not fall under another type
# one (CARDINAL): Numerals that do not fall under another type
# two (CARDINAL): Numerals that do not fall under another type
# 86 (CARDINAL): Numerals that do not fall under another type
# Whiteness (ORG): Companies, agencies, institutions, etc.
# 3 (CARDINAL): Numerals that do not fall under another type
# two (CARDINAL): Numerals that do not fall under another type
# Accidental Definitions (ORG): Companies, agencies, institutions, etc.
# Descriptions (PRODUCT): Objects, vehicles, foods, etc. (not services)
# first (ORDINAL): "first", "second", etc.
# Houyhnhnms (PERSON): People, including fictional
# Houyhnhnms (PERSON): People, including fictional
# 87 (CARDINAL): Numerals that do not fall under another type
# 4 (CARDINAL): Numerals that do not fall under another type
# first (ORDINAL): "first", "second", etc.
# second (ORDINAL): "first", "second", etc.
# Description (PERSON): People, including fictional
# two (CARDINAL): Numerals that do not fall under another type
# two (CARDINAL): Numerals that do not fall under another type
# Cuvier (ORG): Companies, agencies, institutions, etc.
# 88 (CARDINAL): Numerals that do not fall under another type
# Cuvier (ORG): Companies, agencies, institutions, etc.
# first (ORDINAL): "first", "second", etc.
# second (ORDINAL): "first", "second", etc.
# Acid (ORG): Companies, agencies, institutions, etc.
# Aristotelian (NORP): Nationalities or religious or political groups
# Kinds (GPE): Countries, cities, states
# Kind (PERSON): People, including fictional
# Kinds (GPE): Countries, cities, states
# Kind (PERSON): People, including fictional
# Kind (PERSON): People, including fictional
# one (CARDINAL): Numerals that do not fall under another type
# 89 (CARDINAL): Numerals that do not fall under another type
# Kind (PERSON): People, including fictional
# two (CARDINAL): Numerals that do not fall under another type
# only one (CARDINAL): Numerals that do not fall under another type
# two (CARDINAL): Numerals that do not fall under another type
# Nominalists (ORG): Companies, agencies, institutions, etc.
# Nominalist (NORP): Nationalities or religious or political groups
# 43 (CARDINAL): Numerals that do not fall under another type
# Bain (PERSON): People, including fictional
# 71 (DATE): Absolute or relative dates or periods
# 75 (CARDINAL): Numerals that do not fall under another type
# i. (ORG): Companies, agencies, institutions, etc.
# 73 (CARDINAL): Numerals that do not fall under another type
# Bain (PERSON): People, including fictional
# Man is Mortal (WORK_OF_ART): Titles of books, songs, etc.
# one (CARDINAL): Numerals that do not fall under another type
# Nature (WORK_OF_ART): Titles of books, songs, etc.
# Bain (PERSON): People, including fictional
# two (CARDINAL): Numerals that do not fall under another type
# 90 (CARDINAL): Numerals that do not fall under another type
# Archbishop Whately's (PERSON): People, including fictional
# the Westminster Review (ORG): Companies, agencies, institutions, etc.
# January, 1828 (DATE): Absolute or relative dates or periods
# Aristotelian (NORP): Nationalities or religious or political groups
# three (CARDINAL): Numerals that do not fall under another type
# first (ORDINAL): "first", "second", etc.
# second (ORDINAL): "first", "second", etc.
# two (CARDINAL): Numerals that do not fall under another type
# 44 (CARDINAL): Numerals that do not fall under another type
# Archbishop Whately (ORG): Companies, agencies, institutions, etc.
# 9th (ORDINAL): "first", "second", etc.
# 145 (CARDINAL): Numerals that do not fall under another type
# Definitions (ORG): Companies, agencies, institutions, etc.
# De Morgan (PERSON): People, including fictional
# Archbishop Whately (ORG): Companies, agencies, institutions, etc.
# the Nominal Definition (LAW): Named documents made into laws.
# 36 (CARDINAL): Numerals that do not fall under another type
# De Morgan (PERSON): People, including fictional
# 91 (CARDINAL): Numerals that do not fall under another type
# three (CARDINAL): Numerals that do not fall under another type
# first (ORDINAL): "first", "second", etc.
# Realistic (NORP): Nationalities or religious or political groups
# Aristotle (ORG): Companies, agencies, institutions, etc.
# Hobbes (PERSON): People, including fictional
# two (CARDINAL): Numerals that do not fall under another type
# Euclid's Elements (ORG): Companies, agencies, institutions, etc.
# two (CARDINAL): Numerals that do not fall under another type
# one (CARDINAL): Numerals that do not fall under another type
# two (CARDINAL): Numerals that do not fall under another type
# 92 (CARDINAL): Numerals that do not fall under another type
# C A. (PERSON): People, including fictional
# C A (ORG): Companies, agencies, institutions, etc.
# one (CARDINAL): Numerals that do not fall under another type
# first (ORDINAL): "first", "second", etc.
# third (ORDINAL): "first", "second", etc.
# 93 (CARDINAL): Numerals that do not fall under another type
# Dragon (ORG): Companies, agencies, institutions, etc.
# Dragon (ORG): Companies, agencies, institutions, etc.
# Thing (ORG): Companies, agencies, institutions, etc.
# 45 (CARDINAL): Numerals that do not fall under another type
# first (ORDINAL): "first", "second", etc.
# one (CARDINAL): Numerals that do not fall under another type
# 94 (CARDINAL): Numerals that do not fall under another type
# 6 (CARDINAL): Numerals that do not fall under another type
# One (CARDINAL): Numerals that do not fall under another type
# Demonstration (GPE): Countries, cities, states
# Whewell (PERSON): People, including fictional
# the Inductive Sciences: (ORG): Companies, agencies, institutions, etc.
# Whewell (PERSON): People, including fictional
# 95 (CARDINAL): Numerals that do not fall under another type
# Definitions (ORG): Companies, agencies, institutions, etc.
# Plato (PERSON): People, including fictional
# Dialogues (ORG): Companies, agencies, institutions, etc.
# Gorgias (PERSON): People, including fictional
# Pilate (ORG): Companies, agencies, institutions, etc.
# first (ORDINAL): "first", "second", etc.
# first (ORDINAL): "first", "second", etc.
# first (ORDINAL): "first", "second", etc.
# one (CARDINAL): Numerals that do not fall under another type
# charlatan (NORP): Nationalities or religious or political groups
# 96 (CARDINAL): Numerals that do not fall under another type
# James Mackintosh (PERSON): People, including fictional
# first (ORDINAL): "first", "second", etc.
# ...
# nine (CARDINAL): Numerals that do not fall under another type
# nine (CARDINAL): Numerals that do not fall under another type
# nine (CARDINAL): Numerals that do not fall under another type
# one (CARDINAL): Numerals that do not fall under another type
# 178 (CARDINAL): Numerals that do not fall under another type
# February, 1850 (DATE): Absolute or relative dates or periods
# 179 (CARDINAL): Numerals that do not fall under another type
# first (ORDINAL): "first", "second", etc.
# first (ORDINAL): "first", "second", etc.
# first (ORDINAL): "first", "second", etc.
# first (ORDINAL): "first", "second", etc.
# one (CARDINAL): Numerals that do not fall under another type
# 343 (CARDINAL): Numerals that do not fall under another type
# enumerationem simplicem (PERSON): People, including fictional
# Notwithstanding (GPE): Countries, cities, states
# a hundred (CARDINAL): Numerals that do not fall under another type
# five (CARDINAL): Numerals that do not fall under another type
# the age of seventy (DATE): Absolute or relative dates or periods
# Sixth (ORDINAL): "first", "second", etc.
# Laplace (ORG): Companies, agencies, institutions, etc.
# Essai
# Philosophique sur les Probabilités (WORK_OF_ART): Titles of books, songs, etc.
# the Analysis of Chances (ORG): Companies, agencies, institutions, etc.
# 180 (CARDINAL): Numerals that do not fall under another type
# 181 (CARDINAL): Numerals that do not fall under another type
# 18 (CARDINAL): Numerals that do not fall under another type
# 19 (DATE): Absolute or relative dates or periods
# Laplace (ORG): Companies, agencies, institutions, etc.
# two (CARDINAL): Numerals that do not fall under another type
# 344 (CARDINAL): Numerals that do not fall under another type
# two (CARDINAL): Numerals that do not fall under another type
# two (CARDINAL): Numerals that do not fall under another type
# two (CARDINAL): Numerals that do not fall under another type
# Case I. Let (PERSON): People, including fictional
# second (ORDINAL): "first", "second", etc.
# 300 (CARDINAL): Numerals that do not fall under another type
# 200 (CARDINAL): Numerals that do not fall under another type
# 100 (CARDINAL): Numerals that do not fall under another type
# 300 (CARDINAL): Numerals that do not fall under another type
# 200 (CARDINAL): Numerals that do not fall under another type
# only 100 (CARDINAL): Numerals that do not fall under another type
# 2 (CARDINAL): Numerals that do not fall under another type
# 1 (CARDINAL): Numerals that do not fall under another type
# three (CARDINAL): Numerals that do not fall under another type
# three (CARDINAL): Numerals that do not fall under another type
# two (CARDINAL): Numerals that do not fall under another type
# six (CARDINAL): Numerals that do not fall under another type
# three (CARDINAL): Numerals that do not fall under another type
# three (CARDINAL): Numerals that do not fall under another type
# three (CARDINAL): Numerals that do not fall under another type
# two (CARDINAL): Numerals that do not fall under another type
# three (CARDINAL): Numerals that do not fall under another type
# six (CARDINAL): Numerals that do not fall under another type
# third (ORDINAL): "first", "second", etc.
# two (CARDINAL): Numerals that do not fall under another type
# two (CARDINAL): Numerals that do not fall under another type
# two (CARDINAL): Numerals that do not fall under another type
# M. Which (PERSON): People, including fictional
# third (ORDINAL): "first", "second", etc.
# first (ORDINAL): "first", "second", etc.
# second (ORDINAL): "first", "second", etc.
# four (CARDINAL): Numerals that do not fall under another type
# four (CARDINAL): Numerals that do not fall under another type
# 2 (CARDINAL): Numerals that do not fall under another type
# 1 (CARDINAL): Numerals that do not fall under another type
# 2 to 3 (CARDINAL): Numerals that do not fall under another type
# 4 to 3 (CARDINAL): Numerals that do not fall under another type
# twelve (CARDINAL): Numerals that do not fall under another type
# 8 (CARDINAL): Numerals that do not fall under another type
# 4 (CARDINAL): Numerals that do not fall under another type
# eight (CARDINAL): Numerals that do not fall under another type
# only 4 (CARDINAL): Numerals that do not fall under another type
# four (CARDINAL): Numerals that do not fall under another type
# 3 (CARDINAL): Numerals that do not fall under another type
# seven (CARDINAL): Numerals that do not fall under another type
# twelve (CARDINAL): Numerals that do not fall under another type
# four (CARDINAL): Numerals that do not fall under another type
# three (CARDINAL): Numerals that do not fall under another type
# 4 to 3 (CARDINAL): Numerals that do not fall under another type
# 4/7 (CARDINAL): Numerals that do not fall under another type
# 3/7 (CARDINAL): Numerals that do not fall under another type
# 6 (CARDINAL): Numerals that do not fall under another type
# 345 (CARDINAL): Numerals that do not fall under another type
# two (CARDINAL): Numerals that do not fall under another type
# 1/mPn
# P. (QUANTITY): Measurements, as of weight or distance
# 1/6 (CARDINAL): Numerals that do not fall under another type
# 1 (CARDINAL): Numerals that do not fall under another type
# 6 (CARDINAL): Numerals that do not fall under another type
# 1/36 (CARDINAL): Numerals that do not fall under another type
# first (ORDINAL): "first", "second", etc.
# six (CARDINAL): Numerals that do not fall under another type
# six (CARDINAL): Numerals that do not fall under another type
# thirty-six (CARDINAL): Numerals that do not fall under another type
# six (CARDINAL): Numerals that do not fall under another type
# thirty-six (CARDINAL): Numerals that do not fall under another type
# three (CARDINAL): Numerals that do not fall under another type
# 1/6P3 (CARDINAL): Numerals that do not fall under another type
# 1/216 (CARDINAL): Numerals that do not fall under another type
# two hundred and sixteen (CARDINAL): Numerals that do not fall under another type
# Laplace (ORG): Companies, agencies, institutions, etc.
# sixth (ORDINAL): "first", "second", etc.
# two (CARDINAL): Numerals that do not fall under another type
# two (CARDINAL): Numerals that do not fall under another type
# One (CARDINAL): Numerals that do not fall under another type
# two (CARDINAL): Numerals that do not fall under another type
# 346 (CARDINAL): Numerals that do not fall under another type
# Venn (PERSON): People, including fictional
# Caius College (ORG): Companies, agencies, institutions, etc.
# Cambridge (GPE): Countries, cities, states
# The Logic of Chance (WORK_OF_ART): Titles of books, songs, etc.
# one (CARDINAL): Numerals that do not fall under another type
# Logic and Evidence (ORG): Companies, agencies, institutions, etc.
# many years (DATE): Absolute or relative dates or periods
# Venn (PERSON): People, including fictional
# Venn (PERSON): People, including fictional
# 347 (CARDINAL): Numerals that do not fall under another type
# The Extension Of Derivative Laws (WORK_OF_ART): Titles of books, songs, etc.
# 1 (CARDINAL): Numerals that do not fall under another type
# this, day (DATE): Absolute or relative dates or periods
# night (TIME): Times smaller than a day
# day (DATE): Absolute or relative dates or periods
# one (CARDINAL): Numerals that do not fall under another type
# second (ORDINAL): "first", "second", etc.
# one (CARDINAL): Numerals that do not fall under another type
# one (CARDINAL): Numerals that do not fall under another type
# 348 (CARDINAL): Numerals that do not fall under another type
# 2 (CARDINAL): Numerals that do not fall under another type
# morrow (DATE): Absolute or relative dates or periods
# one (CARDINAL): Numerals that do not fall under another type
# thousands (CARDINAL): Numerals that do not fall under another type
# five thousand years (DATE): Absolute or relative dates or periods
# morrow (DATE): Absolute or relative dates or periods
# five
# thousand years (DATE): Absolute or relative dates or periods
# earth (LOC): Non-GPE locations, mountain ranges, bodies of water
# five thousand years (DATE): Absolute or relative dates or periods
# one day (DATE): Absolute or relative dates or periods
# five thousand years (DATE): Absolute or relative dates or periods
# a single day (DATE): Absolute or relative dates or periods
# the entire five thousand years (DATE): Absolute or relative dates or periods
# 349 (CARDINAL): Numerals that do not fall under another type
# 3 (CARDINAL): Numerals that do not fall under another type
# this day (DATE): Absolute or relative dates or periods
# five thousand
# years (DATE): Absolute or relative dates or periods
# the end of twenty thousand (DATE): Absolute or relative dates or periods
# five thousand years (DATE): Absolute or relative dates or periods
# twenty thousand (CARDINAL): Numerals that do not fall under another type
# one (CARDINAL): Numerals that do not fall under another type
# five
# thousand years (DATE): Absolute or relative dates or periods
# twenty thousand (CARDINAL): Numerals that do not fall under another type
# morrow (DATE): Absolute or relative dates or periods
# five thousand years (DATE): Absolute or relative dates or periods
# five thousand years (DATE): Absolute or relative dates or periods
# Niagara (PERSON): People, including fictional
# 350 (CARDINAL): Numerals that do not fall under another type
# first (ORDINAL): "first", "second", etc.
# Laplace (ORG): Companies, agencies, institutions, etc.
# first (ORDINAL): "first", "second", etc.
# earth (LOC): Non-GPE locations, mountain ranges, bodies of water
# 351 (CARDINAL): Numerals that do not fall under another type
# XX (GPE): Countries, cities, states
# 1 (CARDINAL): Numerals that do not fall under another type
# Archbishop Whately (PERSON): People, including fictional
# Ferguson (ORG): Companies, agencies, institutions, etc.
# Resemblance of Relations (ORG): Companies, agencies, institutions, etc.
# colonies (GPE): Countries, cities, states
# colonies (GPE): Countries, cities, states
# Parliament (ORG): Companies, agencies, institutions, etc.
# Parliament (ORG): Companies, agencies, institutions, etc.
# two (CARDINAL): Numerals that do not fall under another type
# one (CARDINAL): Numerals that do not fall under another type
# two (CARDINAL): Numerals that do not fall under another type
# two (CARDINAL): Numerals that do not fall under another type
# 2 (CARDINAL): Numerals that do not fall under another type
# Two (CARDINAL): Numerals that do not fall under another type
# one (CARDINAL): Numerals that do not fall under another type
# one (CARDINAL): Numerals that do not fall under another type
# Method (PRODUCT): Objects, vehicles, foods, etc. (not services)
# 352 (CARDINAL): Numerals that do not fall under another type
# one (CARDINAL): Numerals that do not fall under another type
# 353 (CARDINAL): Numerals that do not fall under another type
# one (CARDINAL): Numerals that do not fall under another type
# Grecian (ORG): Companies, agencies, institutions, etc.
# Etruscan (NORP): Nationalities or religious or political groups
# Egyptian (NORP): Nationalities or religious or political groups
# 3 (CARDINAL): Numerals that do not fall under another type
# one (CARDINAL): Numerals that do not fall under another type
# first (ORDINAL): "first", "second", etc.
# nine (CARDINAL): Numerals that do not fall under another type
# ten (CARDINAL): Numerals that do not fall under another type
# 354 (CARDINAL): Numerals that do not fall under another type
# nine (CARDINAL): Numerals that do not fall under another type
# one (CARDINAL): Numerals that do not fall under another type
# two (CARDINAL): Numerals that do not fall under another type
# the last century (DATE): Absolute or relative dates or periods
# Hartley (PERSON): People, including fictional
# Hartley (ORG): Companies, agencies, institutions, etc.
# Dugald
# Stewart (PERSON): People, including fictional
# 183 (CARDINAL): Numerals that do not fall under another type
# Hartley (ORG): Companies, agencies, institutions, etc.
# i. (ORG): Companies, agencies, institutions, etc.
# 16 (CARDINAL): Numerals that do not fall under another type
# Priestley (ORG): Companies, agencies, institutions, etc.
# 355 (CARDINAL): Numerals that do not fall under another type
# 356 (CARDINAL): Numerals that do not fall under another type
# The Evidence Of The Law Of Universal
# Causation
#
# § 1 (WORK_OF_ART): Titles of books, songs, etc.
# Method (PRODUCT): Objects, vehicles, foods, etc. (not services)
# Difference (ORG): Companies, agencies, institutions, etc.
# two (CARDINAL): Numerals that do not fall under another type
# one (CARDINAL): Numerals that do not fall under another type
# one (CARDINAL): Numerals that do not fall under another type
# Inductive Methods (WORK_OF_ART): Titles of books, songs, etc.
# first (ORDINAL): "first", "second", etc.
# one (CARDINAL): Numerals that do not fall under another type
# 357 (CARDINAL): Numerals that do not fall under another type
# Belief (PERSON): People, including fictional
# one (CARDINAL): Numerals that do not fall under another type
# one (CARDINAL): Numerals that do not fall under another type
# one (CARDINAL): Numerals that do not fall under another type
# two (CARDINAL): Numerals that do not fall under another type
# One (CARDINAL): Numerals that do not fall under another type
# one (CARDINAL): Numerals that do not fall under another type
# one (CARDINAL): Numerals that do not fall under another type
# 358 (CARDINAL): Numerals that do not fall under another type
# Greek (NORP): Nationalities or religious or political groups
# Aristotle (PERSON): People, including fictional
# Chance and Spontaneity (ORG): Companies, agencies, institutions, etc.
# a full half (CARDINAL): Numerals that do not fall under another type
# one (CARDINAL): Numerals that do not fall under another type
# 2 (CARDINAL): Numerals that do not fall under another type
# 184 (CARDINAL): Numerals that do not fall under another type
# Baden Powell (PERSON): People, including fictional
# Powell (PERSON): People, including fictional
# pp. (ORG): Companies, agencies, institutions, etc.
# 100 (CARDINAL): Numerals that do not fall under another type
# daily (DATE): Absolute or relative dates or periods
# this year (DATE): Absolute or relative dates or periods
# last year (DATE): Absolute or relative dates or periods
# 185 (CARDINAL): Numerals that do not fall under another type
# 3 (CARDINAL): Numerals that do not fall under another type
# 3. (CARDINAL): Numerals that do not fall under another type
# 1 (CARDINAL): Numerals that do not fall under another type
# 359 (CARDINAL): Numerals that do not fall under another type
# first (ORDINAL): "first", "second", etc.
# enumerationem simplicem (PERSON): People, including fictional
# one (CARDINAL): Numerals that do not fall under another type
# one (CARDINAL): Numerals that do not fall under another type
# fourth (ORDINAL): "first", "second", etc.
# 3 (CARDINAL): Numerals that do not fall under another type
# 186 (CARDINAL): Numerals that do not fall under another type
# one (CARDINAL): Numerals that do not fall under another type
# four (CARDINAL): Numerals that do not fall under another type
# one (CARDINAL): Numerals that do not fall under another type
# 361 (CARDINAL): Numerals that do not fall under another type
# the Law of Causation (LAW): Named documents made into laws.
# 4 (CARDINAL): Numerals that do not fall under another type
# Palmerston (GPE): Countries, cities, states
# Palmerston (GPE): Countries, cities, states
# the Law of Universal Causation (LAW): Named documents made into laws.
# one (CARDINAL): Numerals that do not fall under another type
# the present day (DATE): Absolute or relative dates or periods
# First (ORDINAL): "first", "second", etc.
# 187 (CARDINAL): Numerals that do not fall under another type
# 2 (CARDINAL): Numerals that do not fall under another type
# 3. (CARDINAL): Numerals that do not fall under another type
# 362 (CARDINAL): Numerals that do not fall under another type
# first (ORDINAL): "first", "second", etc.
# second (ORDINAL): "first", "second", etc.
# 363 (CARDINAL): Numerals that do not fall under another type
# 188 One (CARDINAL): Numerals that do not fall under another type
# France (GPE): Countries, cities, states
# M. Taine (GPE): Countries, cities, states
# Revue (PERSON): People, including fictional
# Deux Mondes (PERSON): People, including fictional
# one (CARDINAL): Numerals that do not fall under another type
# Processing chunk 4/5
